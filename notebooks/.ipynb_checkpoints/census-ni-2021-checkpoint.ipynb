# %% [markdown]
# # CS5002: Programming Principles and Practice
#
# ## Practical P3: Data analysis and visualisation Python

# %%
import json
import pandas as pd

# %% [markdown]
# We start with exploring the content of the dataset.

# %%
df = pd.read_csv("../data/census-2021-public-microdata-teaching-sample.csv")

# %%
df
# Out:
#        SerialNum  AGE_BAND_AGG8  COB_AGG3  ECONOMIC_ACTIVITY_10M  \
# 0              1              2         1                      1
# 1              2              7         1                      1
# 2              3              7         1                      5
# 3              4              7         1                      7
# 4              5              3         1                      1
# ...          ...            ...       ...                    ...
# 16889      16890              6         1                      1
# 16890      16891              2         1                      6
# 16891      16892              3         1                      1
# 16892      16893              6         1                      3
# 16893      16894              1         1                     -8
#
#        ETHNIC_GROUP_AGG2  HEALTH_IN_GENERAL  FAMILY_TYPE  HH_SOCGRADE4  \
# 0                      1                  2            4             3
# 1                      1                  5            2            -8
# 2                      1                  4            2            -8
# 3                      1                  1            2            -8
# 4                      1                  2            2             3
# ...                  ...                ...          ...           ...
# 16889                  1                  3            1             4
# 16890                  1                  2            5             3
# 16891                  1                  1            4             4
# 16892                  1                  4            2             4
# 16893                  1                  2            2             3
#
#        HOURS_PER_WEEK_WORKED  IN_FULL_TIME_EDUCATION  INDUSTRY_CURRENT_10A  \
# 0                          2                       2                     8
# 1                          1                       2                     8
# 2                         -8                       2                    -8
# 3                         -8                       2                    -8
# 4                          4                       2                     4
# ...                      ...                     ...                   ...
# 16889                      3                       2                     7
# 16890                     -8                       1                    -8
# 16891                      2                       2                     8
# 16892                     -8                       2                    -8
# 16893                     -8                      -8                    -8
#
#        LEGAL_PARTNERSHIP_STATUS_6A  OCCUPATION_CURRENT_1DIGIT  \
# 0                                1                          4
# 1                                2                          2
# 2                                2                         -8
# 3                                2                         -8
# 4                                1                          8
# ...                            ...                        ...
# 16889                            1                          9
# 16890                            1                         -8
# 16891                            1                          6
# 16892                            2                         -8
# 16893                           -8                         -8
#
#        RELIGION_BELONG_TO  RELIGION_BROUGHT_UP_IN  SEX  UR_RESIDENCE_TYPE
# 0                       1                      -8    1                  1
# 1                       3                      -8    2                  1
# 2                       1                      -8    2                  1
# 3                       8                       2    1                  1
# 4                       1                      -8    2                  1
# ...                   ...                     ...  ...                ...
# 16889                   2                      -8    2                  1
# 16890                   1                      -8    2                  1
# 16891                   1                      -8    1                  1
# 16892                   2                      -8    1                  1
# 16893                   7                       4    1                  1
#
# [16894 rows x 17 columns]

# %% [markdown]
# Next, we read the JSON file with the interpretations of categories.

# %%
with open("../data/data_dictionary.json", "r") as read_file:
    labels = json.load(read_file)

# %%
labels
# Out:
# {'FAMILY_TYPE': {'1': 'Not in a family',
#   '2': 'Married or civil partnership couple family',
#   '3': 'Cohabiting couple family',
#   '4': 'Lone parent family (female)',
#   '5': 'Lone parent family (male)',
#   '-8': 'No code required (CE residents)'},
#  'UR_RESIDENCE_TYPE': {'1': 'Resident in a household',
#   '2': 'Resident in a communal establishment'}}

# %%
labels['FAMILY_TYPE']['2']
# Out:
# 'Married or civil partnership couple family'

# %% [markdown]
# ## **Basic requirements**

# %% [markdown]
# For census data (variable df) - Check that the data match expected format by checking that total equals to the sum of stats in each row

# %%
df['SerialNum']
# Out:
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#          ...
# 16889    16890
# 16890    16891
# 16891    16892
# 16892    16893
# 16893    16894
# Name: SerialNum, Length: 16894, dtype: int64

# %%
duplicate_rows = df[df.duplicated(keep=False)]
 
if not duplicate_rows.empty:
    print("Duplicate rows:")
    print(duplicate_rows)
else:
    print("No duplicate rows.")
# Out:
# No duplicate rows.

# %% [markdown]
# Detect duplicate rows
